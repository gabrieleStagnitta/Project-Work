# %% [markdown]
# # Generazione di un dataset avanzato usando Gemma 4

# %% [markdown]
# # Descrizione del problema

# %% [markdown]
# All'interno di questo Jupyter Notebook è presente il contenuto del punto 6 del [Notebook 1: Generazione Dataset Elementare](01_Generazione_Dataset_Elementare.ipynb)

# %% [markdown]
# Per la generazione di un dataset avanzato ho deciso di chiedere l'aiuto delle LLM. Invece di optare per una normale query all'interno di interfacce web commerciali (come Gemini o soluzioni simili), ho deciso di utilizzare uno strumento molto più versatile e professionale, ovvero Gemma 4. Questo è un modello linguistico di grandi dimensione (Large Language Model) sviluppato da Google che ho configurato ed eseguito localmente tramite la piattaforma Ollama. Questa architettura ha permesso di aggirare i vincoli legati al rate limiting e i costi di consumo tipici delle API basate su cloud (come ad esempio Gemini, anch'essa di Google), garantendo al contempo il controllo totale sui parametri di generazione (come ad esempio la formattazione nativa della risposta). Per maggiori informazioni, è possibile consultare la documentazione ufficiale di [Gemma 4](https://ai.google.dev/gemma/docs/core/model_card_4?hl=it).

# %% [markdown]
# In questo dataset ho deciso appositamente di ignorare la creazione di finti nomi e finte email in quanto non richieste dal PW.

# %% [markdown]
# ### Come eseguire il codice di questo Jupyter Notebook

# %% [markdown]
# __Questo Jupyter Notebook contiene già del codice eseguito a scopo dimostrativo, tuttavia a seguire è disponibile una breve guida passo-passo qualora si desiderasse configurare l'ambiente ed eseguirlo nuovamente__

# %% [markdown]
# Per eseguire correttamente questo Notebook e avviare la generazione del dataset tramite il modello locale, segui questi passaggi preliminari:
#
# - Ollama deve essere installato direttamente sul tuo sistema operativo per poter ospitare il modello in locale.
# * **Windows / Mac / Linux:** Scarica e installa l'applicazione ufficiale dal sito [ollama.com](https://ollama.com).
# - Dopo di che, va scaricato ed installato il modello. Da powershell, basta runnare il comando: *ollama run gemma4* (9.6 GB richiesti)
# - Una volta installato, per rimuovere il modello basta utilizzare il comando: *ollama rm gemma4*

# %%
# %pip install pandas ollama pydantic
# Out:
# Requirement already satisfied: pandas in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (3.0.3)
# Requirement already satisfied: ollama in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (0.6.2)
# Requirement already satisfied: pydantic in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (2.13.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: httpx>=0.27 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: anyio in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from httpx>=0.27->ollama) (4.14.0)
# Requirement already satisfied: certifi in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from httpx>=0.27->ollama) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from httpx>=0.27->ollama) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\gabri\desktop\project work\project-work\cose di codice\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Sviluppo del codice

# %% [markdown]
# Import delle librerie:

# %%
import json
import pandas as pd
import random
from ollama import Client
from pydantic import BaseModel, Field

# %% [markdown]
# Struttura base dei parametri di generazione:

# %%
class TicketSintetico(BaseModel):
    title: str = Field(
        description="Un titolo breve, specifico e realistico."
    )
    body: str = Field(
        description=(
            "Il corpo del ticket. Deve contenere una descrizione breve (1-2 frasi) del problema reale. "
            "NON usare placeholder, parentesi quadre, simboli di markup o istruzioni di compilazione (es. '[Descrivere qui...]'). "
            "Non è obbligatorio inserire nominativi di applicazioni/servizi ma, se lo fai, utilizza nomi verosimili (non usare ad esempio modulo X o endpoint x)"
            "Il testo deve essere testo pronto, discorsivo e già compilato, scritto dal punto di vista dell'utente o del dipendente che sta riscontrando il problema in prima persona"
        )
    )

# %% [markdown]
# Funzione della generazione ticket con gemma. Qui viene formattato il prompt della richiesta da fare a Gemma per la creazione di un determinato ticket. I parametri sono:
# - categoria: la categoria del ticket
# - priorità: la priorità del problema
# - esperienza: il livello di esperienza nel settore specifico della categoria da parte dell'utente
# - colloqualità: il tono da utilizzare per la stesura del ticket
# - nome_utente: informazione extra da utilizzare in maniera facoltativa che rappresenta se voler aggiungere il nome dell'utente durante la stesura del ticket
# - typo: booleano che specifica se richiedere l'inserimento di un typo o meno

# %% [markdown]
# Il prompt finale nasce da diverse prove al fine di ottenere un risultato più realistico possibile

# %% [markdown]
# L'output della funzione sarà una tupla, contenente body e il title del ticket.

# %%
client = Client()
def genera_ticket_con_gemma(categoria, priorita,esperienza,colloqualità,incipit,titolo,typo=False):
    prompt_utente = f"""Genera un ticket di assistenza aziendale in lingua italiana con queste caratteristiche:
    - Categoria del ticket: {categoria}. Questo rappresenta di quale argomento deve parlare il ticket.
    - Priorità del problema: {priorita}. Cerca di adattare il contenuto del ticket in base a questo livello di priorità (se Alto, è una cosa urgente, se basso, no)
    - Livello di esperienza dell'utente: {esperienza}. Questo rappresenta quanto bene conosce l'argomento della categoria di cui sta parlando.
    - Livello di colloquialità/tono: {colloqualità}

    STILE DI SCRITTURA:
    1. Sii estremamente sintetico. Il testo deve essere composto da massimo 2-3 frasi corte.
    2. Scrivi in prima persona. 
    3. Non usare MAI caratteri speciali di formattazione come asterischi (*), corsivi o grassetti.
    4. Evita deliri o flussi di coscienza lunghi: vai dritto al problema reale.
    5. Se lo ritieni naturale per il tono richiesto, puoi includere il nome dell'utente nel testo. Puoi inventarlo tu, ma fai in modo che non sia un nome palesemente inventato
    6. Forma di saluto iniziale deve essere {incipit} o una sua variante
    7. Se lo ritieni opportuno in base al tono o al livello di esperienza, fai in modo che il titolo del ticket sia più o meno complesso, non limitarti ad usare parole standard
    8. Il titolo deve simulare l'oggetto scritto da un utente reale (breve, a volte sbrigativo o imperfetto). Inizia il titolo UTILIZZANDO OBBLIGATORIAMENTE questa esatta espressione iniziale: "{titolo}". 
    Continua poi la frase completando l'oggetto in modo che si colleghi perfettamente (es. se il titolo è "Non va ", il titolo diventerà "Non va la posta elettronica" o "Non va internet").
    9. Se lo ritieni necessario, in base al contesto e al tono colloquiale, inserisci una brevissima storia di massimo una frase che spieghi come si è generato il problema in questione
    10. Se ritieni che il titolo non sia allineato con la priorità, puoi modificarlo leggermente affinchè lo diventi
    11. Usa parole chiave specifiche in base alla categoria del ticket ({categoria})
    """
    if typo:
        prompt_utente += "\n- Inserisci dove rendi opportuno un typo per rendere il ticket più human like."

    try:
        response = client.chat(
            model='gemma4:2b', 
            messages=[{'role': 'user', 'content': prompt_utente}],
            format={
                'type': 'object',
                'properties': {
                    'title': {'type': 'string'},
                    'body': {'type': 'string'}
                },
                'required': ['title', 'body']
            },
            options={
                'keep_alive': -1,  # -1 dice a Ollama: "Non scaricare MAI il modello finché non si chiude lo script"
                'temperature': 0.4
            }
        )
        dati_ticket = json.loads(response['message']['content'].strip())
        return dati_ticket['title'], dati_ticket['body']
    except Exception as e:
        print(f"Errore durante la generazione locale: {e}")
        return None, None

# %% [markdown]
# Semplicissimo ciclo for responsabile della creazione di *da_fare* ticket.

# %% [markdown]
# Componenti fondamentali:
# - Definizione dei Pool di Input:
#     - Delle semplicissime liste contenenti dei pool di categorie, priorità, livelli di esperienza, ecc... che verranno estratti casualmente all'interno del ciclo. Il loro compito è quello di fornire un incipit di partenza a Gemma, così da indirizzarla di volta in volta nella crezione del ticket (operazione necessaria dato che inizialmente il modello creava sempre ticket simili)
# - L'interno del ciclo for
#     - All'inizio è possibile notare la prensenza di vari random.choices pesati per creare una logica realistica dei dati che verranno realizzati
#     - *titolo, corpo = genera_ticket_con_gemma(categoria, priorità, esperienza, colloqualità,incipit,titolo, attiva_typo)*, chiama la funzione precedentemente descritta e conserva all'interno delle variabili *titolo* e *corpo* il risultato
#     - Viene creato un dizionario e convertito in un dataframe che verrà inserito in all'interno del file csv (in append o in write, in base al fatto se esista già o meno un record al suo interno)

# %%
import pandas as pd
import random

percorso_csv = "output/gemma_v2.csv"
categorie_disponibili = ["Tecnico", "Amministrazione", "Commerciale"]
priorita_disponibili = ["Bassa", "Media", "Alta"]
livelli_esperienza = ["Principiante", "Intermedio", "Esperto/Professionale","Utente occasionale","Primo utente","Avanzato","Primo utilizzo","Utente che si crede esperto ma non lo è"]
livelli_colloquialita = ["Formale e distaccato", "Molto informale e colloquiale", "Frustrato/Arrabbiato","Confuso","Dettagliato","Frettoloso","Sarcastico","Simpaticone"]
pool_incipit = [
    "",                             #(Gemma decide da sola)
    "Ciao, ",
    "Buongiorno. ",
    "Buongiorno! "
    "Eccomi di nuovo, ",
    "Salve, ",
    "Buongiorno, ",
    "Scusate il disturbo, ",
    "Ho un problema: ",
    "Vi scrivo perché ",
    "Non so più che fare... ",
    "Così non posso lavorare! ",
    "Non volevo proprio dirlo, ma ",
    "Ho bisogno di fare una call su ",
    "Creo questo ticket per ",
    "Da stamattina sto provando a ",
    "Dopo l'ultimo aggiornamento, ",
    "Ho già provato a riavviare ",
    "Potete dare un occhiata a ",
    "Ho già provato a riavviare, ma ",
    "Gentile supporto, vi contatto per ",
    "Vorrei segnalare ",
    "Ho necessità di segnalare "
    ""
]
pool_incipit_titolo = [
    "",                                #(Gemma decide da sola)
    "Problema con ",
    "Aiuto: ",
    "Errore ",
    "Bloccato su ",
    "Info per ",
    "Richiesta urgente: ",
    "Non va ",
    "Chiarimento su ",
    "Mancato funzionamento ",
    "Urgente: non va ",
    "Assistenza immediata per ",
    "Procedura per ",
    "Richiesta chiarimenti "
]
da_fare = 138

#controllo se è il primo inserimento o meno
try:
    df_esistente = pd.read_csv(percorso_csv)
    
    if not df_esistente.empty and 'id' in df_esistente.columns:
        ultimo_id_str = df_esistente['id'].iloc[-1]
        id_di_partenza = int(ultimo_id_str.split("-")[1]) + 1
    else:
        id_di_partenza = 0
        
    scrivi_header = False
    print(f"File CSV rilevato con Pandas. Riprendo dall'ID: TK-{id_di_partenza}")

except (FileNotFoundError, pd.errors.EmptyDataError):
    #parto da zero se il file non è stato trovato o è vuoto
    id_di_partenza = 0
    scrivi_header = True
    print("File CSV non trovato o vuoto. Creazione nuovo dataset da TK-0.")

print("-" * 50)

for i in range(0, da_fare):
    id_corrente_numerico = id_di_partenza + i
    stringa_id = f"TK-{id_corrente_numerico}"
    
    categoria = random.choice(categorie_disponibili)
    priorità = random.choice(priorita_disponibili)
    esperienza = random.choice(livelli_esperienza)
    colloqualità = random.choice(livelli_colloquialita)
    attiva_typo = random.choices([True, False], weights=[20, 80])[0]
    incipit = random.choice(pool_incipit)
    titolo = random.choice(pool_incipit_titolo)

    print(f"Generazione in corso... [{categoria} - {priorità} - {esperienza} - {colloqualità} - {attiva_typo}] ({i+1}/{da_fare})")
            
    titolo, corpo = genera_ticket_con_gemma(categoria, priorità, esperienza, colloqualità,incipit,titolo, attiva_typo)
    
    if titolo and corpo:
        singolo_ticket = {
            "id": [stringa_id],
            "title": [titolo],
            "body": [corpo],
            "category": [categoria],
            "priority": [priorità]
        }
        df_singolo = pd.DataFrame(singolo_ticket)
        
        #se è il primo ticket assoluto creato da zero, scrive l'header e apre in 'w'
        if id_corrente_numerico == 0 and scrivi_header:
            df_singolo.to_csv(percorso_csv, index=False, mode='w', header=True)
            scrivi_header = False 
        else:
            df_singolo.to_csv(percorso_csv, index=False, mode='a', header=False)
            
        print(f"Ticket {stringa_id} Creato e SALVATO nel CSV!")
        print(f"Titolo: {titolo}")
        print(f"Corpo:  {corpo[:80]}...") 
        print("-" * 50)
        print()
    else:
        print("Generazione fallita. Salto al successivo.")
        print("-" * 50)

print(f"\nGenerazione conclusa con successo!")
print(f"Trovi tutti i dati aggiornati in tempo reale qui: '{percorso_csv}'.")
# Out:
# File CSV rilevato con Pandas. Riprendo dall'ID: TK-363
# --------------------------------------------------
# Generazione in corso... [Tecnico - Bassa - Primo utilizzo - Simpaticone - False] (1/138)
# Ticket TK-363 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su configurazione account e accesso ai servizi
# Corpo:  Buongiorno! Eccomi di nuovo. Sto cercando di accedere al portale clienti, ma non...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Esperto/Professionale - Dettagliato - False] (2/138)
# Ticket TK-364 Creato e SALVATO nel CSV!
# Titolo: Procedura per configurazione API e autenticazione OAuth 2.0
# Corpo:  Vi scrivo perché sto riscontrando un errore di handshake durante il tentativo di...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Utente che si crede esperto ma non lo è - Frustrato/Arrabbiato - False] (3/138)
# Ticket TK-365 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per problemi di tariffazione non chiari
# Corpo:  Buongiorno, devo capire subito perché la fattura ha un costo extra che nessuno m...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Principiante - Frettoloso - False] (4/138)
# Ticket TK-366 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso al sistema interno dopo aggiornamento
# Corpo:  Potete dare un occhiata a cosa succede? Non riesco proprio ad accedere al CRM da...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Primo utente - Frettoloso - False] (5/138)
# Ticket TK-367 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso ai preventivi clienti
# Corpo:  Non volevo proprio dirlo, ma ho un problema. Non riesco ad accedere ai nuovi pre...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Utente occasionale - Confuso - False] (6/138)
# Ticket TK-368 Creato e SALVATO nel CSV!
# Titolo: Info per accesso al sistema dopo aggiornamento
# Corpo:  Salve, non riesco proprio ad accedere al portale aziendale da stamattina. Ho pro...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Utente che si crede esperto ma non lo è - Frustrato/Arrabbiato - False] (7/138)
# Ticket TK-369 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per Problemi di accesso ai documenti aziendali
# Corpo:  Buongiorno, devo assolutamente capire perché non riesco ad aprire i file amminis...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Intermedio - Frettoloso - True] (8/138)
# Ticket TK-370 Creato e SALVATO nel CSV!
# Titolo: Non va la configurazione dei prezzi su Progetto X
# Corpo:  Così non posso lavorare! Devo aggiornare i listini e ho problemi a far sì che i ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Utente occasionale - Frettoloso - True] (9/138)
# Ticket TK-371 Creato e SALVATO nel CSV!
# Titolo: Errore con la gestione delle spese e i rimborsi
# Corpo:  Buongiorno! Eccomi di nuovo. Devo capire come si fa a caricare le ricevute spese...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Principiante - Formale e distaccato - False] (10/138)
# Ticket TK-372 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Problema nell'accesso ai documenti contabili
# Corpo:  Buongiorno! Eccomi di nuovo. Non riesco ad accedere al modulo per l'invio delle ...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Primo utente - Sarcastico - False] (11/138)
# Ticket TK-373 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Non ricevo i preventivi aggiornati per il Cliente X
# Corpo:  Buongiorno. Mi serve un preventivo commerciale rivisto al volo, perché devo invi...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Avanzato - Formale e distaccato - False] (12/138)
# Ticket TK-374 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Revisione condizioni contrattuali per nuovo servizio
# Corpo:  Gentile supporto, vi contatto per richiedere una revisione dettagliata delle cla...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Utente occasionale - Frettoloso - False] (13/138)
# Ticket TK-375 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso al portale per le scadenze
# Corpo:  Buongiorno, devo assolutamente accedere subito all'area riservata perché ho un p...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Intermedio - Confuso - False] (14/138)
# Ticket TK-376 Creato e SALVATO nel CSV!
# Titolo: Non va l'integrazione dati per il preventivo
# Corpo:  Gentile supporto, vi contatto perché ho un problema con la generazione dei preve...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Utente occasionale - Dettagliato - False] (15/138)
# Ticket TK-377 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sul funzionamento dello stampante di rete
# Corpo:  Buongiorno, ho notato che quando tento di stampare più documenti contemporaneame...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Principiante - Dettagliato - False] (16/138)
# Ticket TK-378 Creato e SALVATO nel CSV!
# Titolo: Problema accesso e gestione documenti amministrativi
# Corpo:  Vorrei segnalare che non riesco ad accedere al portale interno per scaricare la ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Utente che si crede esperto ma non lo è - Confuso - False] (17/138)
# Ticket TK-379 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sulla gestione spese e procedure interne
# Corpo:  Ho bisogno di fare una call su come devo procedere con questa nota spese che ho ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Avanzato - Dettagliato - False] (18/138)
# Ticket TK-380 Creato e SALVATO nel CSV!
# Titolo: Bloccato su configurazione API per il servizio di terze parti
# Corpo:  Non so più che fare con questo modulo. Ho implementato l'ultima versione della l...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Avanzato - Frettoloso - False] (19/138)
# Ticket TK-381 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso al database di produzione
# Corpo:  Così non posso lavorare! Ho bisogno subito un aiuto con il connettore API, è blo...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Utente che si crede esperto ma non lo è - Dettagliato - False] (20/138)
# Ticket TK-382 Creato e SALVATO nel CSV!
# Titolo: Problema di connessione al database aziendale
# Corpo:  Buongiorno! Eccomi di nuovo, ho notato che non riesco ad accedere all'API del CR...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Utente che si crede esperto ma non lo è - Simpaticone - False] (21/138)
# Ticket TK-383 Creato e SALVATO nel CSV!
# Titolo: Procedura per aggiornamento dati anagrafici dipendente
# Corpo:  Ho già provato a riavviare il sistema, ma non riesco ad accedere al modulo di mo...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Intermedio - Dettagliato - False] (22/138)
# Ticket TK-384 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sulla procedura di approvazione spese viaggio
# Corpo:  Buongiorno, vorrei sapere se è necessario allegare la ricevuta originale o se va...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Primo utente - Formale e distaccato - True] (23/138)
# Ticket TK-385 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso al sistema CRM
# Corpo:  Creo questo ticket perché non riesco ad accedere all'area riservata del CRM da c...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Principiante - Formale e distaccato - True] (24/138)
# Ticket TK-386 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su le tariffe promozionali attive
# Corpo:  Scusate il disturbo, vorrei avere conferma riguardo alle condizioni di pagamento...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Esperto/Professionale - Sarcastico - False] (25/138)
# Ticket TK-387 Creato e SALVATO nel CSV!
# Titolo: Bloccato su gestione preventivi complessi per nuovi clienti
# Corpo:  Potete dare un occhiata a questo? Ho bisogno di finalizzare urgentemente il repo...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Principiante - Frettoloso - True] (26/138)
# Ticket TK-388 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Non riesco ad accedere al portale con le credenziali
# Corpo:  Ciao, devo assolutamente fare l'accesso subito perché ho bisogno di approvare de...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Esperto/Professionale - Sarcastico - False] (27/138)
# Ticket TK-389 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso ai documenti di bilancio aziendale
# Corpo:  Vorrei segnalare che non riesco ad accedere al modulo aggiornato per la registra...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Esperto/Professionale - Simpaticone - False] (28/138)
# Ticket TK-390 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Revisione condizioni contrattuali per nuovo partner
# Corpo:  Buongiorno, vorrei rivedere alcune clausole relative al prossimo accordo commerc...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Principiante - Frettoloso - False] (29/138)
# Ticket TK-391 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per problemi di preventivo commerciale urgente
# Corpo:  Ho necessità di segnalare che il sistema non mi permette di scaricare i nuovi li...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Utente occasionale - Confuso - False] (30/138)
# Ticket TK-392 Creato e SALVATO nel CSV!
# Titolo: Mancato funzionamento accesso al database clienti
# Corpo:  Scusate il disturbo, non riesco proprio a entrare nel sistema stamattina. Ho pro...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Avanzato - Molto informale e colloquiale - False] (31/138)
# Ticket TK-393 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Problemi di visibilità sui nuovi accordi commerciali
# Corpo:  Da stamattina sto provando a capire perché il nostro nuovo catalogo prodotti non...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Intermedio - Confuso - True] (32/138)
# Ticket TK-394 Creato e SALVATO nel CSV!
# Titolo: Errore con la compilazione dei moduli di spesa
# Corpo:  Creo questo ticket perché non riesco a caricare i documenti per le spese del mes...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Primo utilizzo - Sarcastico - False] (33/138)
# Ticket TK-395 Creato e SALVATO nel CSV!
# Titolo: Non riesco a collegarmi al server di stampa
# Corpo:  Buongiorno. Non capisco perché stia succedendo questo casino con la stampante, è...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Principiante - Simpaticone - True] (34/138)
# Ticket TK-396 Creato e SALVATO nel CSV!
# Titolo: Info per la tariffa che mi è arrivata male
# Corpo:  Non volevo proprio dirlo, ma ho visto l'ultima fattura e qualcosa non quadra. Mi...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Utente che si crede esperto ma non lo è - Frettoloso - False] (35/138)
# Ticket TK-397 Creato e SALVATO nel CSV!
# Titolo: Procedura per gestione preventiva dei costi di transazione
# Corpo:  Ho già provato a riavviare il sistema, ma non riesco ad accedere al modulo aggio...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Principiante - Sarcastico - True] (36/138)
# Ticket TK-398 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso ai documenti amministrativi
# Corpo:  Da stamattina sto provando a scaricare qualche modulo e non funziona nulla. È as...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Avanzato - Molto informale e colloquiale - False] (37/138)
# Ticket TK-399 Creato e SALVATO nel CSV!
# Titolo: Bloccato su configurazione API di terze parti
# Corpo:  Salve, ho un problema serio con l'integrazione dati che non vuole partire. Stavo...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Esperto/Professionale - Frustrato/Arrabbiato - True] (38/138)
# Ticket TK-400 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Problemi di visibilità sui nuovi accordi commerciali
# Corpo:  Ho già provato a riavviare la sessione, ma non riesco ad accedere ai dati aggior...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Utente occasionale - Simpaticone - False] (39/138)
# Ticket TK-401 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso ai documenti amministrativi di recente
# Corpo:  Così non posso lavorare! Ho bisogno urgentemente di accedere a un modulo fiscale...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Primo utilizzo - Simpaticone - False] (40/138)
# Ticket TK-402 Creato e SALVATO nel CSV!
# Titolo: Info per problemi di accesso e documenti amministrativi
# Corpo:  Vorrei segnalare che non riesco ad accedere al portale clienti per scaricare la ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Esperto/Professionale - Frustrato/Arrabbiato - False] (41/138)
# Ticket TK-403 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su l'integrazione API che non risponde correttamente
# Corpo:  Ho un problema: da stamattina il servizio di sincronizzazione dati sta dando err...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Primo utilizzo - Confuso - False] (42/138)
# Ticket TK-404 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su gestione documentazione e pagamenti
# Corpo:  Creo questo ticket per capire come dovrei procedere con la registrazione di una ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Principiante - Confuso - True] (43/138)
# Ticket TK-405 Creato e SALVATO nel CSV!
# Titolo: Bloccato su come fare la nota spese
# Corpo:  Ho un problema: non capisco proprio questa cosa delle note spese. Devo inviare i...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Principiante - Formale e distaccato - False] (44/138)
# Ticket TK-406 Creato e SALVATO nel CSV!
# Titolo: Non riesco ad accedere al sistema CRM dopo l'aggiornamento
# Corpo:  Scusate il disturbo, ho riscontrato un problema di accesso al sistema CRM. Dopo ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Utente che si crede esperto ma non lo è - Dettagliato - False] (45/138)
# Ticket TK-407 Creato e SALVATO nel CSV!
# Titolo: Bloccato su configurazione accesso database utente Rossi
# Corpo:  Ho necessità di segnalare un problema con l'integrazione dati. Ho provato a rico...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Utente che si crede esperto ma non lo è - Sarcastico - True] (46/138)
# Ticket TK-408 Creato e SALVATO nel CSV!
# Titolo: Problema con la gestione dei permessi e l'accesso ai file
# Corpo:  Vi scrivo perché non riesco a scaricare i documenti di progetto, nonostante abbi...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Primo utilizzo - Sarcastico - False] (47/138)
# Ticket TK-409 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per i prezzi che cambiano ogni cinque minuti
# Corpo:  Ho già provato a riavviare, ovviamente non è colpa mia. Volevo solo sapere perch...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Primo utente - Simpaticone - False] (48/138)
# Ticket TK-410 Creato e SALVATO nel CSV!
# Titolo: Errore nell'accesso ai dettagli di un preventivo commerciale
# Corpo:  Ciao, ho bisogno di aiuto con la visualizzazione dei prezzi su un preventivo che...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Utente occasionale - Confuso - False] (49/138)
# Ticket TK-411 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Non riesco ad accedere al sistema CRM dopo l'aggiornamento
# Corpo:  Ho bisogno di fare una call su questo problema. Ho aggiornato il software stamat...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Esperto/Professionale - Confuso - False] (50/138)
# Ticket TK-412 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Problemi di accesso ai permessi amministrativi per il nuovo progetto
# Corpo:  Gentile supporto, vi contatto perché non riesco ad accedere a determinate sezion...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Intermedio - Sarcastico - False] (51/138)
# Ticket TK-413 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso al portale per la gestione delle spese
# Corpo:  Ciao, devo inviare le note spese di questo mese ma il sistema mi continua a dare...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Principiante - Formale e distaccato - False] (52/138)
# Ticket TK-414 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso al portale clienti
# Corpo:  Ho già provato a riavviare il dispositivo, ma non riesco ad accedere all'area ri...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Intermedio - Confuso - False] (53/138)
# Ticket TK-415 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso ai documenti cartacei archiviati
# Corpo:  Vi scrivo perché non riesco a trovare il modulo aggiornato per la dichiarazione ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Utente occasionale - Frustrato/Arrabbiato - False] (54/138)
# Ticket TK-416 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso al portale per le pratiche amministrative
# Corpo:  Ho un problema: non riesco a scaricare i moduli necessari dal vostro portale. Ho...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Intermedio - Simpaticone - True] (55/138)
# Ticket TK-417 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sullo stato della mia ultima busta paga
# Corpo:  Ciao, ho già provato a controllare l'area riservata ma non trovo i dettagli del ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Avanzato - Simpaticone - False] (56/138)
# Ticket TK-418 Creato e SALVATO nel CSV!
# Titolo: Info per connessione VPN instabile dopo l'ultimo aggiornamento
# Corpo:  Ciao, da quando ho fatto l'aggiornamento mi scollega continuamente la VPN. È un ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Utente occasionale - Frettoloso - False] (57/138)
# Ticket TK-419 Creato e SALVATO nel CSV!
# Titolo: Non riesco ad aprire i file PDF di progetto
# Corpo:  Da stamattina sto provando a lavorare sui report, ma non mi aprono i file PDF ch...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Principiante - Molto informale e colloquiale - False] (58/138)
# Ticket TK-420 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sullo sconto per il nuovo servizio
# Corpo:  Dopo l'ultimo aggiornamento, volevo sapere se posso ancora approfittare dello sc...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Utente occasionale - Confuso - False] (59/138)
# Ticket TK-421 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Non trovo le istruzioni per l'ultima nota spese
# Corpo:  Buongiorno, ho un problema con la sezione amministrazione online. Ho provato a c...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Primo utente - Molto informale e colloquiale - False] (60/138)
# Ticket TK-422 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Dove trovo le scartoffie per l'ultima nota spese?
# Corpo:  Vi scrivo perché non riesco proprio a trovare i moduli giusti per la gestione de...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Primo utente - Sarcastico - False] (61/138)
# Ticket TK-423 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su le condizioni contrattuali per i nuovi clienti
# Corpo:  Scusate il disturbo, ma mi serve un chiarimento immediato sulle ultime modifiche...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Intermedio - Simpaticone - True] (62/138)
# Ticket TK-424 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sul funzionamento della nuova interfaccia di reportistica
# Corpo:  Buongiorno! Eccomi di nuovo, ho bisogno di capire come filtrare i dati nel modul...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Intermedio - Dettagliato - True] (63/138)
# Ticket TK-425 Creato e SALVATO nel CSV!
# Titolo: Errore nell'accesso al portale di gestione spese
# Corpo:  Dopo l'ultimo aggiornamento, ho notato che non riesco ad caricare i nuovi rendic...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Utente occasionale - Frettoloso - False] (64/138)
# Ticket TK-426 Creato e SALVATO nel CSV!
# Titolo: Errore connessione VPN aziendale
# Corpo:  Ho necessità di segnalare che non riesco ad accedere al sistema da remoto. Ho pr...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Esperto/Professionale - Frettoloso - False] (65/138)
# Ticket TK-427 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso al server di produzione
# Corpo:  Ciao. Non riesco ad autenticarmi sul server principale da circa un'ora ormai. Ho...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Primo utente - Formale e distaccato - False] (66/138)
# Ticket TK-428 Creato e SALVATO nel CSV!
# Titolo: Procedura per configurazione accesso al database interno
# Corpo:  Gentile supporto, vi contatto perché non riesco a stabilire la connessione all'a...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Primo utente - Confuso - False] (67/138)
# Ticket TK-429 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Non trovo come fare a scaricare i moduli amministrativi
# Corpo:  Non so più che fare con questa cosa. Ho bisogno di accedere ai documenti per la ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Utente occasionale - Simpaticone - False] (68/138)
# Ticket TK-430 Creato e SALVATO nel CSV!
# Titolo: Info per l'accesso ai documenti aziendali
# Corpo:  Vorrei segnalare che non riesco ad accedere a qualche documento amministrativo i...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Primo utilizzo - Frustrato/Arrabbiato - False] (69/138)
# Ticket TK-431 Creato e SALVATO nel CSV!
# Titolo: Info per i costi e le condizioni contrattuali
# Corpo:  Vorrei segnalare che non capisco assolutamente questi nuovi costi aggiuntivi. Mi...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Utente che si crede esperto ma non lo è - Dettagliato - True] (70/138)
# Ticket TK-432 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso al database clienti
# Corpo:  Buongiorno! Eccomi di nuovo. Ho provato a resettare la password e ho seguito tut...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Intermedio - Frustrato/Arrabbiato - False] (71/138)
# Ticket TK-433 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso ai preventivi clienti
# Corpo:  Non so più che fare, è un disastro totale. Devo inviare subito dei prezzi a tre ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Utente che si crede esperto ma non lo è - Sarcastico - False] (72/138)
# Ticket TK-434 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Il sistema di gestione documenti non carica i file
# Corpo:  Potete dare un occhiata a questo problema? È assurdo che il caricamento dei PDF ...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Avanzato - Molto informale e colloquiale - False] (73/138)
# Ticket TK-435 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso alle tariffe B2B
# Corpo:  Gentile supporto, vi contatto perché ho un problema serio con il calcolo delle n...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Primo utente - Molto informale e colloquiale - False] (74/138)
# Ticket TK-436 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Devo fare un pagamento urgente ma non trovo i dati
# Corpo:  Buongiorno! Eccomi di nuovo, spero che stiate bene. Sto cercando di sistemare un...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Principiante - Sarcastico - False] (75/138)
# Ticket TK-437 Creato e SALVATO nel CSV!
# Titolo: Errore nell'accesso ai moduli di gestione spese aziendali
# Corpo:  Ho necessità di segnalare che non riesco ad accedere al portale per la compilazi...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Intermedio - Molto informale e colloquiale - False] (76/138)
# Ticket TK-438 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso ai preventivi clienti
# Corpo:  Buongiorno! Scusa se ti scrivo per questa cosa così banale, ma ho un piccolo pro...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Esperto/Professionale - Frettoloso - False] (77/138)
# Ticket TK-439 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per problemi di gestione spese aziendali
# Corpo:  Creo questo ticket perché non riesco ad accedere al portale amministrativo delle...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Principiante - Formale e distaccato - False] (78/138)
# Ticket TK-440 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Accesso bloccato al sistema CRM dopo aggiornamento
# Corpo:  Ho necessità di segnalare che non riesco ad accedere al sistema CRM. Dopo aver e...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Utente occasionale - Molto informale e colloquiale - True] (79/138)
# Ticket TK-441 Creato e SALVATO nel CSV!
# Titolo: Procedura per richiedere la nota spese
# Corpo:  Vi scrivo perché non ho capito bene come funziona l'invio delle note spese. Ho p...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Utente occasionale - Confuso - False] (80/138)
# Ticket TK-442 Creato e SALVATO nel CSV!
# Titolo: Bloccato su l'accesso ai documenti amministrativi
# Corpo:  Buongiorno. Non riesco proprio a trovare i moduli per la dichiarazione dei costi...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Intermedio - Confuso - False] (81/138)
# Ticket TK-443 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per problemi di preventivo e costi
# Corpo:  Vi scrivo perché non riesco ad accedere al modulo di calcolo dei prezzi che mi s...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Esperto/Professionale - Formale e distaccato - False] (82/138)
# Ticket TK-444 Creato e SALVATO nel CSV!
# Titolo: Procedura per configurazione accesso API su ambiente di staging
# Corpo:  Ho bisogno di fare una call riguardo l'implementazione dell'autenticazione OAuth...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Esperto/Professionale - Sarcastico - False] (83/138)
# Ticket TK-445 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso al database di produzione
# Corpo:  Ho un problema: non riesco ad eseguire la query X-23 sul DB principale, e questo...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Primo utilizzo - Formale e distaccato - False] (84/138)
# Ticket TK-446 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Problemi nell'accesso ai documenti amministrativi
# Corpo:  Ciao, devo accedere a un modulo per la compilazione dei dati fiscali. Non riesco...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Esperto/Professionale - Frustrato/Arrabbiato - False] (85/138)
# Ticket TK-447 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su gestione spese e plafond di spesa
# Corpo:  Dopo l'ultimo aggiornamento, non riesco ad accedere al modulo per la rendicontaz...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Utente occasionale - Dettagliato - False] (86/138)
# Ticket TK-448 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sulla tariffazione per i nuovi contratti B2B
# Corpo:  Ho già provato a riavviare la connessione, ma il problema persiste. Ho bisogno d...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Principiante - Molto informale e colloquiale - False] (87/138)
# Ticket TK-449 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su come si fa a trovare i moduli per le ferie
# Corpo:  Buongiorno! Eccomi di nuovo. Volevo sapere, perché sono un po' confuso con il po...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Utente occasionale - Frettoloso - False] (88/138)
# Ticket TK-450 Creato e SALVATO nel CSV!
# Titolo: Aiuto: Non riesco ad accedere ai prezzi per il nuovo cliente
# Corpo:  Non volevo proprio dirlo, ma non trovo i listini aggiornati sul portale. Ho appe...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Principiante - Sarcastico - False] (89/138)
# Ticket TK-451 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Non trovo l'ultima ricevuta spese di ottobre
# Corpo:  Ho necessità di segnalare che il portale amministrativo è un disastro. Volete da...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Intermedio - Simpaticone - True] (90/138)
# Ticket TK-452 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su la procedura di invio nota spese
# Corpo:  Gentile supporto, vi contatto perché ho qualche dubbio sulla modalità corretta d...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Avanzato - Confuso - False] (91/138)
# Ticket TK-453 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso ai documenti aziendali
# Corpo:  Scusate il disturbo, devo capire come recuperare i vecchi atti amministrativi di...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Utente che si crede esperto ma non lo è - Molto informale e colloquiale - False] (92/138)
# Ticket TK-454 Creato e SALVATO nel CSV!
# Titolo: Non va di far passare i costi extra sul preventivo
# Corpo:  Ciao! Senta, stavo guardando il preventivo che mi avete mandato e non capisco pe...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Utente che si crede esperto ma non lo è - Confuso - False] (93/138)
# Ticket TK-455 Creato e SALVATO nel CSV!
# Titolo: Bloccato su come attivare le funzionalità di preventivo
# Corpo:  Vorrei segnalare che non capisco bene la sezione dei prezzi. Ho provato a fare u...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Primo utente - Frettoloso - True] (94/138)
# Ticket TK-456 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per problemi di connessione al network
# Corpo:  Salve, devo segnalare che la mia connessione internet non funziona da stamattina...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Utente che si crede esperto ma non lo è - Frettoloso - False] (95/138)
# Ticket TK-457 Creato e SALVATO nel CSV!
# Titolo: Mancato funzionamento gestione preventivi e prezzi
# Corpo:  Gentile supporto, vi contatto per un problema con la sezione commerciale. Ho pro...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Avanzato - Dettagliato - False] (96/138)
# Ticket TK-458 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso al database di produzione dopo l'ultimo aggiornamento
# Corpo:  Da stamattina sto provando a connettermi all'API e ricevo un errore 401, anche s...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Avanzato - Molto informale e colloquiale - False] (97/138)
# Ticket TK-459 Creato e SALVATO nel CSV!
# Titolo: Non funziona l'accesso a X
# Corpo:  Buongiorno! Eccomi di nuovo. Sto cercando di finalizzare un preventivo per il cl...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Primo utente - Sarcastico - False] (98/138)
# Ticket TK-460 Creato e SALVATO nel CSV!
# Titolo: Info per pagamenti e documenti aziendali
# Corpo:  Ciao. Non capisco come si fa a scaricare le ultime fatture di aprile, è un casin...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Primo utilizzo - Frettoloso - False] (99/138)
# Ticket TK-461 Creato e SALVATO nel CSV!
# Titolo: Mancato funzionamento accesso area clienti
# Corpo:  Da stamattina sto provando a accedere all'area riservata ma mi chiede sempre le ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Avanzato - Formale e distaccato - True] (100/138)
# Ticket TK-462 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso al portale amministrativo
# Corpo:  Ciao, ho riscontrato che i permessi di accesso al sistema CRM sono stati revocat...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Intermedio - Formale e distaccato - True] (101/138)
# Ticket TK-463 Creato e SALVATO nel CSV!
# Titolo: Assistenza immediata per connessione rete instabile e intermittenza dati
# Corpo:  Ho un problema: la connettività di rete è estremamente instabile da stamattina. ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Esperto/Professionale - Confuso - True] (102/138)
# Ticket TK-464 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Non riesco ad accedere al database di produzione
# Corpo:  Ho un problema con l'accesso al DB principale. Credo che ci sia un errore nelle ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Utente occasionale - Dettagliato - False] (103/138)
# Ticket TK-465 Creato e SALVATO nel CSV!
# Titolo: Info per gestione spese e note spese
# Corpo:  Gentile supporto, vi contatto perché non riesco ad accedere al portale di invio ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Utente occasionale - Confuso - False] (104/138)
# Ticket TK-466 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su come si gestiscono le spese e i rimborsi
# Corpo:  Ciao, ho un dubbio sulla procedura per l'invio delle ricevute. Ho appena ricevut...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Primo utente - Molto informale e colloquiale - False] (105/138)
# Ticket TK-467 Creato e SALVATO nel CSV!
# Titolo: Errore accesso area riservata per documenti
# Corpo:  Ciao! Creo questo ticket perché non riesco ad accedere all'area clienti per scar...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Principiante - Frustrato/Arrabbiato - False] (106/138)
# Ticket TK-468 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso ai documenti amministrativi
# Corpo:  Gentile supporto, vi contatto per questo disastro totale. Non riesco proprio ad ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Esperto/Professionale - Molto informale e colloquiale - False] (107/138)
# Ticket TK-469 Creato e SALVATO nel CSV!
# Titolo: Info per configurazione API di terze parti
# Corpo:  Vorrei segnalare che ho un piccolo problema con l'integrazione dell'API esterna....
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Primo utente - Sarcastico - False] (108/138)
# Ticket TK-470 Creato e SALVATO nel CSV!
# Titolo: Procedura per accedere al sistema dopo l'ultimo aggiornamento
# Corpo:  Ho necessità di segnalare che non riesco ad accedere al sistema con le credenzia...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Utente che si crede esperto ma non lo è - Frustrato/Arrabbiato - True] (109/138)
# Ticket TK-471 Creato e SALVATO nel CSV!
# Titolo: Mancato funzionamento dell'accesso ai documenti contabili
# Corpo:  Ciao, devo assolutamente accedere al fascicolo X prima di fine giornata. Non rie...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Intermedio - Frettoloso - False] (110/138)
# Ticket TK-472 Creato e SALVATO nel CSV!
# Titolo: Bloccato su gestione spese e approvazioni
# Corpo:  Ho necessità di segnalare un problema con la procedura di avanzamento delle note...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Avanzato - Sarcastico - False] (111/138)
# Ticket TK-473 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su problemi di latenza e connettività VPN
# Corpo:  Così non posso lavorare! Ho notato un aumento inspiegabile della latenza sulla c...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Utente occasionale - Frustrato/Arrabbiato - False] (112/138)
# Ticket TK-474 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso ai prezzi per i nuovi clienti
# Corpo:  Potete dare un occhiata a questo problema? Ho provato ad accedere all'area riser...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Utente che si crede esperto ma non lo è - Simpaticone - False] (113/138)
# Ticket TK-475 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso ai documenti di spesa
# Corpo:  Non so più che fare... Sto cercando di recuperare i moduli per la nota spese ma ...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Utente occasionale - Frustrato/Arrabbiato - False] (114/138)
# Ticket TK-476 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Il sistema di gestione progetti non mi carica i file
# Corpo:  Da stamattina sto provando ad accedere al progetto Alpha, ma il caricamento dei ...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Intermedio - Confuso - False] (115/138)
# Ticket TK-477 Creato e SALVATO nel CSV!
# Titolo: Procedura per accedere ai documenti contabili di marzo
# Corpo:  Ho un problema: non riesco a scaricare i report spese dell'ultimo mese. Ho prova...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Primo utente - Frustrato/Arrabbiato - False] (116/138)
# Ticket TK-478 Creato e SALVATO nel CSV!
# Titolo: Urgente: non va l'accesso al sistema CRM
# Corpo:  Da stamattina sto provando a entrare nel sistema ma mi dà sempre errore di crede...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Alta - Esperto/Professionale - Dettagliato - False] (117/138)
# Ticket TK-479 Creato e SALVATO nel CSV!
# Titolo: Errore nell'accesso ai dati di fatturazione cliente
# Corpo:  Ho necessità di segnalare un problema critico con l'integrazione dei dati commer...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Primo utente - Confuso - False] (118/138)
# Ticket TK-480 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso ai dettagli di un preventivo
# Corpo:  Ho un problema: non riesco a trovare il prezzo finale per la fornitura X. Ho pro...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Utente che si crede esperto ma non lo è - Frustrato/Arrabbiato - False] (119/138)
# Ticket TK-481 Creato e SALVATO nel CSV!
# Titolo: Errore nell'accesso ai dati amministrativi utente Rossi
# Corpo:  Ciao. Non riesco a scaricare i report di spesa del mese scorso, e questo è un pr...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Avanzato - Frettoloso - False] (120/138)
# Ticket TK-482 Creato e SALVATO nel CSV!
# Titolo: Bloccato su configurazione API dopo l'ultimo aggiornamento
# Corpo:  Dopo l'ultimo aggiornamento, non riesco a connettere il servizio X al nuovo endp...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Esperto/Professionale - Molto informale e colloquiale - False] (121/138)
# Ticket TK-483 Creato e SALVATO nel CSV!
# Titolo: Problemi di configurazione prezzi su preventivo commerciale
# Corpo:  Buongiorno! Eccomi di nuovo, ho un piccolo problema con la generazione dei preve...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Utente occasionale - Molto informale e colloquiale - False] (122/138)
# Ticket TK-484 Creato e SALVATO nel CSV!
# Titolo: Errore nel preventivo per i nuovi clienti
# Corpo:  Scusate il disturbo, volevo chiedervi un aiuto con la sezione prezzi sul sito. S...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Bassa - Principiante - Frustrato/Arrabbiato - False] (123/138)
# Ticket TK-485 Creato e SALVATO nel CSV!
# Titolo: Info per l'accesso ai documenti aziendali
# Corpo:  Creo questo ticket perché non riesco a trovare il modulo di richiesta spese. Ho ...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Principiante - Confuso - False] (124/138)
# Ticket TK-486 Creato e SALVATO nel CSV!
# Titolo: Non va l'accesso per i nuovi clienti
# Corpo:  Dopo l'ultimo aggiornamento, non riesco a far vedere la sezione prezzi ai miei c...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Alta - Intermedio - Sarcastico - False] (125/138)
# Ticket TK-487 Creato e SALVATO nel CSV!
# Titolo: Bloccato su accesso al database dopo l'ultimo aggiornamento
# Corpo:  Buongiorno! Eccomi di nuovo, perché il sistema è tornato a fare i capricci. Non ...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Esperto/Professionale - Formale e distaccato - False] (126/138)
# Ticket TK-488 Creato e SALVATO nel CSV!
# Titolo: Bloccato su finalizzazione accordi B2B
# Corpo:  Non volevo proprio dirlo, ma ho riscontrato un ritardo nell'accesso ai dati di f...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Principiante - Frustrato/Arrabbiato - False] (127/138)
# Ticket TK-489 Creato e SALVATO nel CSV!
# Titolo: Errore accesso ai documenti amministrativi
# Corpo:  Ho un problema: Non riesco assolutamente ad accedere ai moduli di spesa o a scar...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Primo utilizzo - Frustrato/Arrabbiato - True] (128/138)
# Ticket TK-490 Creato e SALVATO nel CSV!
# Titolo: Problema con l'accesso al sistema interno dopo aggiornamento
# Corpo:  Da stamattina sto provando a entrare nel software e mi dà solo errore 403. Non c...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Media - Avanzato - Dettagliato - False] (129/138)
# Ticket TK-491 Creato e SALVATO nel CSV!
# Titolo: Richiesta urgente: Problema di connettività API dopo aggiornamento sistema
# Corpo:  Vi scrivo perché ho riscontrato un errore 503 quando tento di accedere all'endpo...
# --------------------------------------------------
#
# Generazione in corso... [Tecnico - Bassa - Principiante - Sarcastico - True] (130/138)
# Ticket TK-492 Creato e SALVATO nel CSV!
# Titolo: Chiarimento su perché non si carica la pagina
# Corpo:  Non so più che fare... Dunque, guardate qui: mi sembra di aver cliccato su qualc...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Intermedio - Dettagliato - False] (131/138)
# Ticket TK-493 Creato e SALVATO nel CSV!
# Titolo: Problemi nell'accesso ai documenti amministrativi aziendali
# Corpo:  Creo questo ticket per segnalare che non riesco ad accedere al modulo di richies...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Alta - Primo utente - Dettagliato - False] (132/138)
# Ticket TK-494 Creato e SALVATO nel CSV!
# Titolo: Non riesco ad accedere ai documenti contabili di questo mese
# Corpo:  Non so più che fare, ho un problema urgente con l'accesso al sistema amministrat...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Esperto/Professionale - Frustrato/Arrabbiato - False] (133/138)
# Ticket TK-495 Creato e SALVATO nel CSV!
# Titolo: Non ricevo i preventivi aggiornati per il progetto Alpha
# Corpo:  Ho già provato a riavviare la dashboard, ma continua a non visualizzare le ultim...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Intermedio - Molto informale e colloquiale - False] (134/138)
# Ticket TK-496 Creato e SALVATO nel CSV!
# Titolo: Errore nel calcolo preventivo dei servizi aggiuntivi
# Corpo:  Scusate il disturbo, devo capire perché quando guardo i prezzi per l'espansione ...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Media - Intermedio - Formale e distaccato - True] (135/138)
# Ticket TK-497 Creato e SALVATO nel CSV!
# Titolo: Procedura per la gestione delle tariffe e preventivi
# Corpo:  Scusate il disturbo, vorrei avere chiarimenti riguardo l'attuale struttura tarif...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Primo utente - Dettagliato - False] (136/138)
# Ticket TK-498 Creato e SALVATO nel CSV!
# Titolo: Errore nell'accesso ai dettagli dei costi per il prossimo trimestre
# Corpo:  Vi scrivo perché ho difficoltà a visualizzare la proiezione completa dei costi o...
# --------------------------------------------------
#
# Generazione in corso... [Commerciale - Bassa - Primo utilizzo - Confuso - False] (137/138)
# Ticket TK-499 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sulle condizioni di acquisto e costi nascosti
# Corpo:  Gentile supporto, vi contatto per capire meglio i prezzi. Ho visto un preventivo...
# --------------------------------------------------
#
# Generazione in corso... [Amministrazione - Media - Utente occasionale - Confuso - False] (138/138)
# Ticket TK-500 Creato e SALVATO nel CSV!
# Titolo: Richiesta chiarimenti sulla procedura di gestione spese
# Corpo:  Vi scrivo perché ho un dubbio su come devo inviare le ricevute per la nota spese...
# --------------------------------------------------
#
#
# Generazione conclusa con successo!
# Trovi tutti i dati aggiornati in tempo reale qui: 'output/gemma_v2.csv'.

# %% [markdown]
# I ticket sono stati creati eseguendo il codice in modalità batch, variando ogni volta la struttura del prompt, inserendo o rimuovendo dettagli, con lo scopo di rendere il dataset più eterogeneo. I prompt e gli incipit presenti in questo Notebook sono quelli che hanno dato dei risultati più bilanciati.

# %% [markdown]
# Ho deciso per tal motivo di effettuare un piccolo shuffling dei record, mantenendo ovviamente l'ordine degli id, con lo scopo di neutralizzare eventuali bias legati alla sequenzialità delle varie fasi.

# %%
import pandas as pd
percorso_csv = "output/ticket_utenti_gemma_shuffled.csv"
df = pd.read_csv("output/gemma_v2.csv")
#isolo per conservare la colonna degli id
ids = df['id'].copy()
#mischio casualmente tutte le atre colonne
df_features_shuffled = df[['title', 'body', 'category', 'priority']].sample(frac=1, random_state=42).reset_index(drop=True)
df_omogeneo = pd.concat([ids, df_features_shuffled], axis=1)
df_omogeneo.to_csv(percorso_csv, index=False, mode='w', header=True)

# %% [markdown]
# # Conclusioni

# %% [markdown]
# - Inizialmente la scelta era ricaduta sulla versione standard e completa del modello Gemma 4. Sebbene l'accuratezza e la diversificazione dei testi fossero ottimali, ho notato una complessità computazionale non da ignorare ed sono andato alla ricerca di alternative più leggere e sostenibili localmente.
#
# - Ho pertanto sperimentato l'introduzione di varianti ottimizzate e quantizzate a parametri ridotti, nello specifico le release da 2 miliardi (e2b) e 4 miliardi di parametri (e4b). Sebbene queste architetture abbiano garantito un'esecuzione radicalmente più fulminea e un'impronta di memoria minima sul sistema, i test sul campo hanno evidenziato una forte "pigrizia semantica"; si sono presentati fenomeni di ripetitività strutturale, generando schemi sintattici quasi identici per i ticket appartenenti alle medesime categorie (quasi nulla di diverso dai ticket generati nel Jupyter 01).
#
# - Poiché l'eterogeneità e la variabilità semantica del dataset sono requisiti fondamentali per evitare l'overfitting e garantire una corretta generalizzazione dei successivi classificatori di Machine Learning, ho stabilito che la qualità del dato dovesse prevalere sulle tempistiche di computazione. Sono dunque ritornato definitivamente al modello base standard di Gemma 4, accettando requisiti hardware più stringenti in cambio di un dataset testuale autentico, eterogeneo e strutturalmente solido.

# %% [markdown]
# Diamo un occhiata ai ticket generati da Gemma per validarne la qualità prima di procedere con la generazione del numero di ticket richiesto dal PW.

# %%
df_anteprima = pd.read_csv("output/ticket_utenti_gemma.csv")
print("*** TICKET GEMMA ***")
df_anteprima.head(5)["body"]
# Out:
# *** TICKET GEMMA ***
# 0    Ciao, vorrei richiedere un chiarimento relativ...
# 1    Vi scrivo perché ho un dubbio sui prezzi che m...
# 2    Vi scrivo perché non riesco ad accedere alla s...
# 3    Buongiorno, ho notato che alcuni articoli nel ...
# 4    Salve, scusa ma non riesco ad accedere al port...
# Name: body, dtype: str

# %% [markdown]
# __Una EDA più accurata è disponibile all'interno del Jupyter 03.__
